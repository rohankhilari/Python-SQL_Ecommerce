# %%
print("hii")
# Out:
# hii

# %%
import pymysql
from sqlalchemy import create_engine
import numpy as np 
import pandas as pd
df_customers=pd.read_csv("E:\ExcelR\Data analysis projects\Eccomarce\Target Sales Dataset\customers.csv",encoding="utf-8")
print(df_customers)
df_geolocation=pd.read_csv("E:\ExcelR\Data analysis projects\Eccomarce\Target Sales Dataset\geolocation.csv",encoding="utf-8")
print(df_geolocation)
df_order_items=pd.read_csv("E:\ExcelR\Data analysis projects\Eccomarce\Target Sales Dataset\order_items.csv",encoding="utf-8")
print(df_order_items)
df_orders=pd.read_csv("E:\ExcelR\Data analysis projects\Eccomarce\Target Sales Dataset\orders.csv",encoding="utf-8")
print(df_orders)
df_payments=pd.read_csv("E:\ExcelR\Data analysis projects\Eccomarce\Target Sales Dataset\payments.csv",encoding="utf-8")
print(df_payments)
df_products=pd.read_csv("E:\ExcelR\Data analysis projects\Eccomarce\Target Sales Dataset\products.csv",encoding="utf-8")
print(df_products)
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_sellers=pd.read_csv("E:\ExcelR\Data analysis projects\Eccomarce\Target Sales Dataset\sellers.csv",encoding="utf-8")
print(df_sellers)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
engine_mysql=create_engine("mysql+pymysql://root:12345@localhost:3306/Ecomarce")
try:
    engine_mysql
    print("connection succesfull")
except:
    print("unable to connect")
# Out:
# connection succesfull

# %%
df_customers.to_sql(name="customers",con=engine_mysql,if_exists="append",index="False")
# Out:
# 99441

# %%
df_geolocation.to_sql(name="geolocation",con=engine_mysql,if_exists="append",index="False")
df_order_items.to_sql(name="oredr_items",con=engine_mysql,if_exists="append",index="False")
df_orders.to_sql(name="orders",con=engine_mysql,if_exists="append",index="False")
# Out:
# 99441

# %%
df_sellers.to_sql(name="sellers",con=engine_mysql,if_exists="append",index="False")
# Out:
# 3095

# %%
df_products.to_sql(name="products",con=engine_mysql,if_exists="append",index="False")
# Out:
# 32951
